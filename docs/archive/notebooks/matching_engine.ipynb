# %% [markdown]
# # Matching Engine
# Run ranking with dietary filters and inspect the top results.

# %%
from app.models import load_recipes
from app.utils.scoring import recommend_recipes

recipes = load_recipes()
recommend_recipes(['egg', 'spinach', 'feta cheese'], recipes, top_k=3, filters=['vegetarian'])
