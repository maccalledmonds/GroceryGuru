# %% [markdown]
# # Data Exploration
# Quickly inspect recipe records and nutrition fields.

# %%
import json
from pathlib import Path

recipes_path = Path('..') / 'data' / 'recipes.json'
with recipes_path.open('r', encoding='utf-8') as f:
    recipes = json.load(f)

len(recipes), recipes[0].keys()
