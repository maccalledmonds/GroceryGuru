# %% [markdown]
# # Ingredient Normalization
# Try typo-heavy ingredient text against the normalization pipeline.

# %%
from app.utils.normalization import normalize_ingredients

sample = ['2 Tomatoes', 'cheddar chese', 'chikn breast']
normalize_ingredients(sample)
